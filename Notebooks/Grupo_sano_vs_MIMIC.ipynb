# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import seaborn as sn
from sklearn import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Análisis lineal<h2>

# %% [markdown]
# <h2>Grupo sano<h2>

# %%
healthy_linear = pd.read_csv("C:/Users/jcruz/Documents/TTB_2020_2_13/csv_datatests/linear_healthy.csv",index_col=0)
healthy_linear.dropna(inplace=True)

healthy_linear = healthy_linear[["mean","variance","skewness","kurtosis"]]
healthy_linear_id = np.repeat(0,71)
healthy_linear
# Out:
#         mean  variance  skewness  kurtosis
# 0   0.757730  0.029774  0.521073 -0.298452
# 1   0.754154  0.017096  0.350030 -0.463467
# 2   0.864584  0.011712 -0.940632  3.402326
# 3   0.850718  0.029892  0.076173 -0.856529
# 4   0.732299  0.050406  0.578449 -0.440829
# ..       ...       ...       ...       ...
# 66  0.740977  0.009778  1.182621  4.250178
# 67  0.642174  0.003417  0.266283  0.136759
# 68  0.766358  0.004966 -0.013394  0.098152
# 69  0.898876  0.014349  0.209839 -0.302257
# 70  0.674986  0.005800  0.645147  0.944853
#
# [71 rows x 4 columns]

# %% [markdown]
# <h2>Mimic III<h2>

# %%
sick_linear = pd.read_csv("C:/Users/jcruz/Documents/TTB_2020_2_13/csv_datatests/linear_sick.csv",index_col=0)
sick_linear.dropna(inplace=True)

sick_linear = sick_linear[["mean","variance","skewness","kurtosis"]]
sick_linear_id = np.repeat(1,195)
sick_linear
# Out:
#          mean  variance  skewness   kurtosis
# 0    0.777117  0.026124 -1.502077   3.909261
# 1    0.583857  0.006984  2.441860  22.536648
# 2    0.881811  0.015847  1.065605  23.810161
# 3    0.866220  0.075346  0.920372   3.773636
# 4    0.751333  0.046699  0.120859  -0.943318
# ..        ...       ...       ...        ...
# 191  1.320596  0.004354  0.334668  -0.240235
# 192  1.304396  0.004139 -0.120586   0.830080
# 193  0.769981  0.005294 -4.651090  26.757337
# 194  0.796193  0.001807 -0.062547  -0.446906
# 195  0.841937  0.001017 -0.165968  -0.090071
#
# [195 rows x 4 columns]

# %% [markdown]
# <h2>Gráficos de dispersión<h2>

# %%
fig = plt.figure(figsize=(7,5))

a = plt.scatter(healthy_linear["mean"],healthy_linear["kurtosis"],color = "steelblue",alpha=0.5)
b = plt.scatter(sick_linear["mean"],sick_linear["kurtosis"],color = "red",alpha =0.5)

plt.title("Gráfico de dispersión (sesgo vs Curtosis)")
plt.ylabel("curtosis")
plt.xlabel("sesgo")
plt.legend((a,b),("Sano","ECV"))
plt.axis
# Out:
# <function matplotlib.pyplot.axis(*args, emit=True, **kwargs)>

# %% [markdown]
# <h2>Histogramas<h2>

# %%
import seaborn as sn

fig = plt.figure(figsize=(10,6))

ax = sn.distplot(healthy_linear["kurtosis"], kde=True,color="steelblue",label="Sanos")
ax.set_title('Histogramas de Curtosis en grupos sano y con ECV')
ax2 = plt.twinx()
ax2 = sn.distplot(sick_linear["kurtosis"], kde=True, ax=ax2,color="red",label="ECV")

fig.legend()
# Out:
# C:\Users\jcruz\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jcruz\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <h2>Análisis no lineal<h2>

# %% [markdown]
# <h2>MIMIC III<h2>

# %%
pathologys = pd.read_csv("C:/Users/jcruz/Documents/TTB_2020_2_13/csv_datatests/Test_100ws.csv")
pathologys = pathologys[["hst_mean","hst_variance","ae_mean","ae_variance","ae_skewness","ae_spectral_entropy","se_mean","se_variance","se_skewness","se_spectral_entropy","hfd_mean","hfd_variance","hfd_skewness","hfd_spectral_entropy","dfa_mean","dfa_variance","dfa_skewness","dfa_spectral_entropy","psd_mean","psd_variance","psd_skewness","psd_spectral_entropy"]]
pathologys_id = np.repeat(1,869)

pathologys["cond_id"] = pathologys_id
pathologyst = pathologys.dropna(inplace=True)
pathologys
# Out:
#      hst_mean  hst_variance   ae_mean  ae_variance  ae_skewness  \
# 0    0.024570      0.002149  0.687467     0.012579    -0.084067
# 1    0.141659      0.005319  0.732894     0.006321    -0.048997
# 2    0.146632      0.005525  0.532273     0.008014    -0.177844
# 3    0.178649      0.013374  0.470510     0.015445     0.056521
# 4    0.109470      0.000517  0.899458     0.001107    -0.185131
# ..        ...           ...       ...          ...          ...
# 863  0.060438      0.004224  0.541597     0.008792    -0.738587
# 865  0.018969      0.000128  0.562526     0.001480     0.994590
# 866  0.039355      0.001994  0.407277     0.018199     0.612575
# 867  0.057872      0.004703  0.416109     0.020682     0.395070
# 868  0.022997      0.001310  0.573020     0.007655    -0.970563
#
#      ae_spectral_entropy   se_mean  se_variance  se_skewness  \
# 0               5.345920  0.765058     0.057268     0.466584
# 1               3.832142  1.169088     0.189573     0.727071
# ...

# %% [markdown]
# <h2>Grupo sano<h2>

# %%
healthy = pd.read_csv("C:/Users/jcruz/Documents/TTB_2020_2_13/csv_datatests//healthy.csv",index_col=0)
healthy = healthy[["cond_id","hst_mean","hst_variance","ae_mean","ae_variance","ae_skewness","ae_spectral_entropy","se_mean","se_variance","se_skewness","se_spectral_entropy","hfd_mean","hfd_variance","hfd_skewness","hfd_spectral_entropy","dfa_mean","dfa_variance","dfa_skewness","dfa_spectral_entropy","psd_mean","psd_variance","psd_skewness","psd_spectral_entropy"]]
healthy_id = np.repeat(0,71)

healthy["cond_id"] = healthy_id
healthy.dropna(inplace=True)
healthy
# Out:
#     cond_id  hst_mean  hst_variance   ae_mean  ae_variance  ae_skewness  \
# 0         0  0.363059      0.008075  0.869854     0.026340    -0.417527
# 1         0  0.376262      0.006391  0.809583     0.020615    -0.436781
# 2         0  0.364838      0.009951  0.896732     0.026714    -0.445707
# 3         0  0.345752      0.007901  0.893707     0.028213    -0.690823
# 4         0  0.391865      0.010604  0.854226     0.028353    -0.378165
# ..      ...       ...           ...       ...          ...          ...
# 66        0  0.331764      0.006503  0.895582     0.017901    -0.618706
# 67        0  0.292186      0.003816  0.920235     0.011360    -0.162415
# 68        0  0.319870      0.003143  0.970820     0.017264    -0.686368
# 69        0  0.287464      0.002676  0.944685     0.007438    -0.605259
# 70        0  0.315481      0.006580  0.899097     0.013112    -0.873366
#
#     ae_spectral_entropy   se_mean  se_variance  se_skewness  ...  \
# ...

# %% [markdown]
# <h2>Histogramas<h2>

# %%
import seaborn as sn

fig = plt.figure(figsize=(10,6))

ax = sn.distplot(healthy["psd_mean"], kde=True,color="steelblue",label="Sanos")
ax.set_title('Histogramas para psd en grupos sano y con ECV')
ax2 = plt.twinx()
ax2 = sn.distplot(pathologys["psd_mean"], kde=True, ax=ax2,color="red",label="ECV")

fig.legend()
# Out:
# C:\Users\jcruz\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jcruz\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <h2>Gráficas de dispersión<h2>

# %%
fig = plt.figure(figsize=(8,8))

a=plt.scatter(healthy['hst_mean'],healthy["psd_mean"],color="blue",alpha=0.5)
b=plt.scatter(pathologys['hst_mean'],pathologys["se_mean"],color="red",alpha=0.5)
plt.title("Gráfica de dispersión (Hurst vs Entropia aprox)")
plt.legend((a,b),("Sano","ECV"))
plt.axis
plt.xlabel("Hurst")
plt.ylabel("Entropia muestral")
# Out:
# Text(0, 0.5, 'Entropia muestral')

# %% [markdown]
# <h2>Set de entrenamiento y prueba<h2>

# %%
targets = healthy['cond_id'].tolist() + pathologys['cond_id'].tolist()
healthy_train = healthy.iloc[:,1:24]
pathologys_train = pathologys.iloc[:,0:22]
X=pd.concat([healthy_train,pathologys_train],ignore_index=True)

#Split data to test and train groups
X_train,X_test,y_train,y_test = train_test_split(X,targets,test_size=0.02,random_state=1)
print(len(X_train))
print(len(y_train))
X.dropna()
# Out:
# 713
# 713
#      hst_mean  hst_variance   ae_mean  ae_variance  ae_skewness  \
# 0    0.363059      0.008075  0.869854     0.026340    -0.417527
# 1    0.376262      0.006391  0.809583     0.020615    -0.436781
# 2    0.364838      0.009951  0.896732     0.026714    -0.445707
# 3    0.345752      0.007901  0.893707     0.028213    -0.690823
# 4    0.391865      0.010604  0.854226     0.028353    -0.378165
# ..        ...           ...       ...          ...          ...
# 723  0.060438      0.004224  0.541597     0.008792    -0.738587
# 724  0.018969      0.000128  0.562526     0.001480     0.994590
# 725  0.039355      0.001994  0.407277     0.018199     0.612575
# 726  0.057872      0.004703  0.416109     0.020682     0.395070
# 727  0.022997      0.001310  0.573020     0.007655    -0.970563
#
#      ae_spectral_entropy   se_mean  se_variance  se_skewness  \
# 0               7.677662  1.258177     0.279852     0.179231
# ...

# %% [markdown]
# <h2>Aprendizaje supervisado<h2>

# %%
classifier = ExtraTreesClassifier()
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

classifier.fit(X_train, y_train)

X_test = sc.fit_transform(X_test)
y_pred = classifier.predict(X_test)

# %% [markdown]
# <h2>Pruebas<h2>

# %%
print("Tamaño de muestra :",len(X_test))
print("Precisión : ", accuracy_score(y_test, y_pred))

confusion_matrix = pd.crosstab(np.array(y_test), np.array(y_pred), rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)
# Out:
# Tamaño de muestra : 15
# Precisión :  1.0
