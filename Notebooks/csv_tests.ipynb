# %%
from TT_utilities import Case, NL_METHODS
from scipy.stats import stats
from pathlib import Path
import pandas as pd
import numpy as np
import re

# %%
RECORD_DIRS = list(Path("./Data").glob("*p00*"))
CASES = list()
for record_dir in RECORD_DIRS:
    record_name = re.search("p[0-9]{6}", str(record_dir))[0]
    c = Case(record_dir.joinpath(record_name))
    c.process()
    CASES.append(c)
# Out:
#  > PROCESSING CASE p000638 optimal signal is "II" present in 4 of 5 records.
#  > < Record 3033264_0005 - Non linear analysis done.
#  > < Record 3033264_0007 - Non linear analysis done.
#  > < Record 3033264_0008 - Non linear analysis done.
#  > < Record 3033264_0009 - Non linear analysis done.
#  < PROCESSED CASE p000638 - 4 valid records kept, 1 records dumped.
# Function _non_linear_analysis_c execution time: 91.48's
#  > PROCESSING CASE p001170 optimal signal is "II" present in 16 of 19 records.
#  > X Record 3612801_0001 - Analysis not possible, rr too short.
#  > X Record 3612801_0002 - Analysis not possible, rr too short.
#  > < Record 3612801_0008 - Non linear analysis done.
#  > X Record 3612801_0011 - Analysis not possible, rr too short.
#  > X Record 3612801_0013 - Analysis not possible, rr too short.
#  > X Record 3612801_0014 - Analysis not possible, rr too short.
#  > < Record 3612801_0017 - Non linear analysis done.
#  > < Record 3612801_0020 - Non linear analysis done.
#  > < Record 3612801_0022 - Non linear analysis done.
#  > < Record 3612801_0025 - Non linear analysis done.
#  > < Record 3612801_0026 - Non linear analysis done.
#  > < Record 3612801_0029 - Non linear analysis done.
#  > < Record 3612801_0032 - Non linear analysis done.
#  > < Record 3415914_0002 - Non linear analysis done.
#  > X Record 3415914_0003 - Analysis not possible, rr too short.
#  > X Record 3415914_0004 - Analysis not possible, rr too short.
#  < PROCESSED CASE p001170 - 9 valid records kept, 10 records dumped.
# Function _non_linear_analysis_c execution time: 115.49's
#  > PROCESSING CASE p001354 optimal signal is "II" present in 24 of 37 records.
#  > < Record 3630869_0004 - Non linear analysis done.
#  > < Record 3630869_0006 - Non linear analysis done.
#  > X Record 3630869_0007 - Analysis not possible, rr too short.
#  > X Record 3630869_0009 - Analysis not possible, rr too short.
#  > < Record 3630869_0015 - Non linear analysis done.
#  > < Record 3630869_0019 - Non linear analysis done.
#  > X Record 3630869_0020 - Analysis not possible, rr too short.
#  > < Record 3630869_0021 - Non linear analysis done.
#  > X Record 3630869_0023 - Analysis not possible, rr too short.
#  > X Record 3630869_0024 - Analysis not possible, rr too short.
#  > < Record 3630869_0025 - Non linear analysis done.
#  > X Record 3630869_0026 - Analysis not possible, rr too short.
#  > X Record 3630869_0032 - Analysis not possible, rr too short.
#  > X Record 3630869_0034 - Analysis not possible, rr too short.
#  > X Record 3630869_0035 - Analysis not possible, rr too short.
#  > X Record 3630869_0037 - Analysis not possible, rr too short.
#  > X Record 3630869_0038 - Analysis not possible, rr too short.
#  > X Record 3630869_0042 - Analysis not possible, rr too short.
#  > X Record 3630869_0043 - Analysis not possible, rr too short.
#  > < Record 3630869_0044 - Non linear analysis done.
#  > X Record 3630869_0047 - Analysis not possible, rr too short.
#  > X Record 3630869_0048 - Analysis not possible, rr too short.
#  > < Record 3630869_0051 - Non linear analysis done.
#  > X Record 3630869_0052 - Analysis not possible, rr too short.
#  < PROCESSED CASE p001354 - 8 valid records kept, 29 records dumped.
# Function _non_linear_analysis_c execution time: 77.65's
#  > PROCESSING CASE p000107 optimal signal is "V" present in 119 of 135 records.
#  > X Record 3805787_0002 - Analysis not possible, rr too short.
#  > X Record 3805787_0005 - Analysis not possible, rr too short.
#  > X Record 3805787_0008 - Analysis not possible, rr too short.
#  > X Record 3805787_0011 - Analysis not possible, rr too short.
#  > X Record 3805787_0014 - Analysis not possible, rr too short.
#  > X Record 3805787_0017 - Analysis not possible, rr too short.
#  > < Record 3805787_0020 - Non linear analysis done.
#  > X Record 3805787_0023 - Analysis not possible, rr too short.
#  > X Record 3805787_0026 - Analysis not possible, rr too short.
#  > X Record 3805787_0029 - Analysis not possible, rr too short.
#  > X Record 3805787_0032 - Analysis not possible, rr too short.
#  > X Record 3805787_0035 - Analysis not possible, rr too short.
#  > X Record 3805787_0038 - Analysis not possible, rr too short.
#  > X Record 3805787_0040 - Analysis not possible, rr too short.
#  > X Record 3805787_0043 - Analysis not possible, rr too short.
#  > X Record 3805787_0044 - Analysis not possible, rr too short.
#  > X Record 3805787_0045 - Analysis not possible, rr too short.
#  > X Record 3805787_0046 - Analysis not possible, rr too short.
#  > X Record 3805787_0047 - Analysis not possible, rr too short.
#  > X Record 3805787_0050 - Analysis not possible, rr too short.
#  > X Record 3805787_0053 - Analysis not possible, rr too short.
#  > < Record 3805787_0056 - Non linear analysis done.
#  > X Record 3805787_0059 - Analysis not possible, rr too short.
#  > X Record 3805787_0062 - Analysis not possible, rr too short.
#  > X Record 3805787_0065 - Analysis not possible, rr too short.
#  > X Record 3805787_0068 - Analysis not possible, rr too short.
#  > X Record 3805787_0071 - Analysis not possible, rr too short.
#  > X Record 3805787_0074 - Analysis not possible, rr too short.
#  > X Record 3805787_0077 - Analysis not possible, rr too short.
#  > X Record 3805787_0080 - Analysis not possible, rr too short.
#  > X Record 3805787_0083 - Analysis not possible, rr too short.
#  > X Record 3805787_0086 - Analysis not possible, rr too short.
#  > X Record 3805787_0089 - Analysis not possible, rr too short.
#  > X Record 3805787_0092 - Analysis not possible, rr too short.
#  > < Record 3805787_0095 - Non linear analysis done.
#  > X Record 3805787_0098 - Analysis not possible, rr too short.
#  > X Record 3805787_0101 - Analysis not possible, rr too short.
#  > < Record 3805787_0104 - Non linear analysis done.
#  > < Record 3805787_0107 - Non linear analysis done.
#  > X Record 3805787_0110 - Analysis not possible, rr too short.
#  > X Record 3805787_0113 - Analysis not possible, rr too short.
#  > X Record 3805787_0116 - Analysis not possible, rr too short.
#  > X Record 3805787_0119 - Analysis not possible, rr too short.
#  > < Record 3805787_0122 - Non linear analysis done.
#  > X Record 3805787_0125 - Analysis not possible, rr too short.
#  > X Record 3805787_0128 - Analysis not possible, rr too short.
#  > X Record 3805787_0131 - Analysis not possible, rr too short.
#  > X Record 3805787_0134 - Analysis not possible, rr too short.
#  > X Record 3805787_0137 - Analysis not possible, rr too short.
#  > X Record 3805787_0140 - Analysis not possible, rr too short.
#  > X Record 3805787_0143 - Analysis not possible, rr too short.
#  > X Record 3805787_0146 - Analysis not possible, rr too short.
#  > X Record 3805787_0149 - Analysis not possible, rr too short.
#  > X Record 3805787_0152 - Analysis not possible, rr too short.
#  > X Record 3805787_0155 - Analysis not possible, rr too short.
#  > X Record 3805787_0158 - Analysis not possible, rr too short.
#  > X Record 3805787_0161 - Analysis not possible, rr too short.
#  > X Record 3805787_0164 - Analysis not possible, rr too short.
#  > X Record 3805787_0167 - Analysis not possible, rr too short.
#  > X Record 3805787_0170 - Analysis not possible, rr too short.
#  > X Record 3805787_0173 - Analysis not possible, rr too short.
#  > X Record 3805787_0176 - Analysis not possible, rr too short.
#  > X Record 3805787_0179 - Analysis not possible, rr too short.
#  > X Record 3805787_0182 - Analysis not possible, rr too short.
#  > X Record 3805787_0185 - Analysis not possible, rr too short.
#  > X Record 3805787_0188 - Analysis not possible, rr too short.
#  > X Record 3805787_0191 - Analysis not possible, rr too short.
#  > X Record 3805787_0194 - Analysis not possible, rr too short.
#  > X Record 3805787_0200 - Analysis not possible, rr too short.
#  > X Record 3805787_0203 - Analysis not possible, rr too short.
#  > X Record 3805787_0206 - Analysis not possible, rr too short.
#  > X Record 3805787_0209 - Analysis not possible, rr too short.
#  > < Record 3805787_0212 - Non linear analysis done.
#  > < Record 3860035_0001 - Non linear analysis done.
#  > < Record 3860035_0004 - Non linear analysis done.
#  > < Record 3860035_0006 - Non linear analysis done.
#  > X Record 3860035_0007 - Analysis not possible, rr too short.
#  > X Record 3860035_0008 - Analysis not possible, rr too short.
#  > X Record 3860035_0009 - Analysis not possible, rr too short.
#  > X Record 3860035_0010 - Analysis not possible, rr too short.
#  > X Record 3860035_0011 - Analysis not possible, rr too short.
#  > X Record 3860035_0012 - Analysis not possible, rr too short.
#  > X Record 3860035_0013 - Analysis not possible, rr too short.
#  > X Record 3860035_0014 - Analysis not possible, rr too short.
#  > X Record 3860035_0015 - Analysis not possible, rr too short.
#  > X Record 3860035_0016 - Analysis not possible, rr too short.
#  > X Record 3860035_0019 - Analysis not possible, rr too short.
#  > X Record 3860035_0020 - Analysis not possible, rr too short.
#  > X Record 3860035_0022 - Analysis not possible, rr too short.
#  > X Record 3860035_0024 - Analysis not possible, rr too short.
#  > X Record 3860035_0027 - Analysis not possible, rr too short.
#  > < Record 3860035_0029 - Non linear analysis done.
#  > X Record 3860035_0030 - Analysis not possible, rr too short.
#  > < Record 3860035_0031 - Non linear analysis done.
#  > < Record 3860035_0032 - Non linear analysis done.
#  > X Record 3860035_0034 - Analysis not possible, rr too short.
#  > X Record 3860035_0037 - Analysis not possible, rr too short.
#  > < Record 3860035_0040 - Non linear analysis done.
#  > X Record 3860035_0043 - Analysis not possible, rr too short.
#  > < Record 3860035_0044 - Non linear analysis done.
#  > X Record 3746356_0002 - Analysis not possible, rr too short.
#  > X Record 3746356_0006 - Analysis not possible, rr too short.
#  > < Record 3746356_0008 - Non linear analysis done.
#  > X Record 3746356_0009 - Analysis not possible, rr too short.
#  > < Record 3746356_0012 - Non linear analysis done.
#  > < Record 3746356_0016 - Non linear analysis done.
#  > < Record 3746356_0018 - Non linear analysis done.
#  > X Record 3746356_0021 - Analysis not possible, rr too short.
#  > X Record 3746356_0024 - Analysis not possible, rr too short.
#  > X Record 3746356_0025 - Analysis not possible, rr too short.
#  > < Record 3746356_0028 - Non linear analysis done.
#  > X Record 3746356_0030 - Analysis not possible, rr too short.
#  > X Record 3168852_0001 - Analysis not possible, rr too short.
#  > < Record 3168852_0002 - Non linear analysis done.
#  > X Record 3168852_0004 - Analysis not possible, rr too short.
#  > X Record 3168852_0007 - Analysis not possible, rr too short.
#  > < Record 3168852_0012 - Non linear analysis done.
#  < PROCESSED CASE p000107 - 22 valid records kept, 113 records dumped.
# Function _non_linear_analysis_c execution time: 401.55's
#  > PROCESSING CASE p000518 optimal signal is "II" present in 7 of 9 records.
#  > X Record 3189537_0001 - Analysis not possible, rr too short.
#  > < Record 3189537_0003 - Non linear analysis done.
#  > < Record 3189537_0005 - Non linear analysis done.
#  > X Record 3189537_0006 - Analysis not possible, rr too short.
#  > X Record 3612035_0002 - Analysis not possible, rr too short.
#  > X Record 3612035_0003 - Analysis not possible, rr too short.
#  > < Record 3612035_0004 - Non linear analysis done.
#  < PROCESSED CASE p000518 - 3 valid records kept, 6 records dumped.
# Function _non_linear_analysis_c execution time: 134.13's
#  > PROCESSING CASE p000906 optimal signal is "II" present in 13 of 14 records.
#  > X Record 3581467_0004 - Analysis not possible, rr too short.
#  > < Record 3581467_0005 - Non linear analysis done.
#  > < Record 3581467_0006 - Non linear analysis done.
#  > X Record 3581467_0007 - Analysis not possible, rr too short.
#  > < Record 3581467_0008 - Non linear analysis done.
#  > X Record 3581467_0009 - Analysis not possible, rr too short.
#  > < Record 3581467_0010 - Non linear analysis done.
#  > < Record 3581467_0011 - Non linear analysis done.
#  > < Record 3581467_0012 - Non linear analysis done.
#  > < Record 3581467_0013 - Non linear analysis done.
#  > < Record 3581467_0014 - Non linear analysis done.
#  > < Record 3581467_0015 - Non linear analysis done.
#  > < Record 3581467_0016 - Non linear analysis done.
#  < PROCESSED CASE p000906 - 10 valid records kept, 4 records dumped.
# Function _non_linear_analysis_c execution time: 587.37's
#  > PROCESSING CASE p000123 optimal signal is "II" present in 7 of 12 records.
#  > X Record 3485814_0001 - Analysis not possible, rr too short.
#  > X Record 3485814_0005 - Analysis not possible, rr too short.
#  > < Record 3485814_0007 - Non linear analysis done.
#  > < Record 3485814_0008 - Non linear analysis done.
#  > < Record 3485814_0018 - Non linear analysis done.
#  > < Record 3348632_0001 - Non linear analysis done.
#  > X Record 3348632_0002 - Analysis not possible, rr too short.
#  < PROCESSED CASE p000123 - 4 valid records kept, 8 records dumped.
# Function _non_linear_analysis_c execution time: 80.55's
#  > PROCESSING CASE p000154 optimal signal is "II" present in 16 of 17 records.
#  > X Record 3783784_0001 - Analysis not possible, rr too short.
#  > X Record 3783784_0002 - Analysis not possible, rr too short.
#  > < Record 3783784_0006 - Non linear analysis done.
#  > X Record 3783784_0007 - Analysis not possible, rr too short.
#  > < Record 3783784_0008 - Non linear analysis done.
#  > X Record 3783784_0009 - Analysis not possible, rr too short.
#  > < Record 3783784_0010 - Non linear analysis done.
#  > X Record 3783784_0013 - Analysis not possible, rr too short.
#  > < Record 3794082_0001 - Non linear analysis done.
#  > < Record 3794082_0002 - Non linear analysis done.
#  > X Record 3794082_0003 - Analysis not possible, rr too short.
#  > < Record 3794082_0005 - Non linear analysis done.
#  > X Record 3794082_0006 - Analysis not possible, rr too short.
#  > < Record 3794082_0007 - Non linear analysis done.
#  > X Record 3794082_0009 - Analysis not possible, rr too short.
#  > < Record 3794082_0011 - Non linear analysis done.
#  < PROCESSED CASE p000154 - 8 valid records kept, 9 records dumped.
# Function _non_linear_analysis_c execution time: 117.32's

# %%
for c in CASES:
    try:
        c.process()
    except ValueError:
        pass
# Out:
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.
# Case already processed, cant do it again.

# %%
# for mean (_m) and variance (_v)
columns = ["case", "record", "cond"]
for m in NL_METHODS:
    columns.extend([m["tag"]+"_m", m["tag"]+"_v"])
print(columns)

CSV_DATA = pd.DataFrame(columns=columns)
CSV_DATA
# Out:
# ['case', 'record', 'cond', 'ae_m', 'ae_v', 'se_m', 'se_v', 'hfd_m', 'hfd_v', 'dfa_m', 'dfa_v', 'psd_m', 'psd_v']
# Empty DataFrame
# Columns: [case, record, cond, ae_m, ae_v, se_m, se_v, hfd_m, hfd_v, dfa_m, dfa_v, psd_m, psd_v]
# Index: []

# %%
for n, c in enumerate(CASES):
    for r in c:
        vals = list()
        for k, v in r.N_LINEAR.items():
            s = stats.describe(v)
            vals.extend([s[2], s[3]])
        row = [c._case_name, r.name, c.pathology] + vals
        CSV_DATA = CSV_DATA.append(pd.Series(data=row, index=columns), ignore_index=True)
CSV_DATA
# Out:
#        case        record                   cond      ae_m      ae_v  \
# 0   p000638  3033264_0005    atrial_fibrillation  1.114328  0.006364
# 1   p000638  3033264_0007    atrial_fibrillation  1.128314  0.005094
# 2   p000638  3033264_0008    atrial_fibrillation  1.182164  0.018420
# 3   p000638  3033264_0009    atrial_fibrillation  1.288425  0.024384
# 4   p001170  3612801_0008    atrial_fibrillation  0.493513  0.039231
# ..      ...           ...                    ...       ...       ...
# 63  p000154  3794082_0001  myocardial_infarction  0.582774  0.053045
# 64  p000154  3794082_0002  myocardial_infarction  0.818121  0.043284
# 65  p000154  3794082_0005  myocardial_infarction  0.672129  0.021658
# 66  p000154  3794082_0007  myocardial_infarction  0.806108  0.034007
# 67  p000154  3794082_0011  myocardial_infarction  0.900190  0.011568
#
#         se_m      se_v     hfd_m     hfd_v     dfa_m     dfa_v     psd_m  \
# 0   1.014952  0.009344  2.062579  0.000213  0.357675  0.003759  0.707119
# 1   1.019000  0.007935  2.062636  0.000320  0.305381  0.004328  0.670582
# 2   1.065136  0.042754  2.043882  0.000665  0.339816  0.009309  0.736152
# 3   1.221510  0.057924  2.020016  0.000103  0.502655  0.002594  0.875502
# 4   0.290480  0.031252  2.104450  0.001487  0.094455  0.002014  0.313816
# ..       ...       ...       ...       ...       ...       ...       ...
# 63  0.473902  0.058073  2.146280  0.005843  0.133404  0.002195  0.410789
# 64  0.758590  0.084491  2.114590  0.002297  0.151744  0.002885  0.506779
# 65  0.575879  0.030423  2.143030  0.002456  0.117214  0.001214  0.403666
# 66  0.768532  0.046890  2.095581  0.000912  0.138230  0.002504  0.546346
# 67  0.902465  0.029012  2.070071  0.000389  0.136627  0.001023  0.538017
#
#        psd_v
# 0   0.004973
# 1   0.006041
# 2   0.008183
# 3   0.001638
# 4   0.015252
# ..       ...
# 63  0.016720
# 64  0.007265
# 65  0.015805
# 66  0.003729
# 67  0.002912
#
# [68 rows x 13 columns]

# %%
CSV_DATA.to_csv("worksample_data.csv")
